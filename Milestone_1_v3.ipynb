# %% [markdown]
# # Milestone 1: Getting to know your data, due Wednesday, April 5, 2017
#
# In the beginning you should get acquainted with the data sources and do some EDA. Sign up for the TMDb [API](https://www.themoviedb.org/documentation/api), and try to download the poster of your favorite movie from within your notebook. Compare the genre entries of IMDb and TMDb for this movie and see if they are the same. Think about and write down some questions that you would like to answer in the following weeks. Keep the storytelling aspect of your final report in mind and do some pen and paper sketches about the visualizations you would like to produce. Include photographs of those sketches in your notebook.
#
# Most of the time a data scientist spends on a project is spend on cleaning the data. We are lucky that the data we have is already pretty clean. The Python interface to the IMDb ftp files does a lot of the additional work of cleaning as well. However, you will notice that the genre list for each movie from both databases can have different lengths. This needs to be changed in order to train a model to predict the movie genre. It is up to you to think about possible ways to address this problem and to implement one of them. There is no absolute right answer here. It depends on your interests and which questions you have in mind for the project.
#
# Optionally, you could also scrape additional data sources, such as Wikipedia, to obtain plot summaries. That data may give you additional useful features for genera classification.
#
# To guide your decision process, provide at least one visualization of how often genres are mentioned together in pairs. Your visualization should clearly show if a horror romance is more likely to occur in the data than a drama romance.
#
# The notebook to submit for this milestone needs to at least include:
#
# - API code to access the genre and movie poster path of your favorite movie
# - Genre for this movie listed by TMDb and IMDb
# - A list of the 10 most popular movies of 2016 from TMDb and their genre obtained via the API
# - Comments on what challenges you see for predicting movie genre based on the data you have, and how to address them
# - Code to generate the movie genre pairs and a suitable visualization of the result
# - Additional visualization sketches and EDA with a focus on movie genres
# - A list of questions you could answer with this and related data. Get creative here!
#
# The EDA questions do not necessarily have to tie into the modeling part later on. Think freely about things that might be interesting, like which actors are very specific to a genre? Are action movies more prone to producing sequels than romances? However, as you keep the focus on movie genres, think also about correlations you might discover that can help building features from the metadata for prediction. Is the length of a movie title correlated with genre?

# %% [markdown]
# ### Install Packages

# %%
#!pip install IMDbPY (only supported in Python 2)
# Documentation for IMDb library:  
        # http://imdbpy.sourceforge.net/support.html#documentation
        # http://imdbpy.sourceforge.net/docs/README.package.txt

# %%
#!pip install tmdbsimple
# Documentation for TMDb library
        # https://github.com/celiao/tmdbsimple/
        # (good resource) https://developers.themoviedb.org/3/discover/movie-discover

# %%
from IPython.display import Image
import urllib

from imdb import IMDb
import tmdbsimple as tmdb
tmdb.API_KEY = 'c5d41f08e55fca6e9f5fc0b6d1735540'

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### IMDb Genre & Poster

# %% [markdown]
# ***Search for Movie by Name & Print Summary***

# %%
imdb = IMDb()
imdb.search_movie('lock stock')
# Out:
# [<Movie id:4701250[http] title:_"Lock Stock and Busted/Sign of a Home Wrecker (2015) (TV Episode)  - Season 1 | Episode 155  - Justice with Judge Mablean" (2014)_>,
#  <Movie id:0982426[http] title:_"Lock Stock and... (1969) (TV Episode)  - Season 1 | Episode 2  - Parkin's Patch" (1969)_>,
#  <Movie id:0243714[http] title:_"Lock, Stock..." (2000)_>,
#  <Movie id:0120735[http] title:_Lock, Stock and Two Smoking Barrels (1998)_>,
#  <Movie id:0157472[http] title:_Clockstoppers (2002)_>,
#  <Movie id:6231970[http] title:_"Rock Story" (2016)_>,
#  <Movie id:0065993[http] title:_Lock, Stock and Barrel (1971) (TV)_>,
#  <Movie id:3592354[http] title:_Clocks Tell the Time (2014)_>,
#  <Movie id:0374557[http] title:_C Block Story (2003)_>,
#  <Movie id:3327432[http] title:_Rock Story (I) (2015)_>,
#  <Movie id:0050972[http] title:_Silk Stockings (1957)_>,
#  <Movie id:4338022[http] title:_Back Stock (2014)_>,
#  <Movie id:0021752[http] title:_The Clock Store (1931)_>,
#  <Movie id:0256346[http] title:_Rockstock (2000) (TV)_>,
#  <Movie id:1340587[http] title:_JackStock (2008)_>,
#  <Movie id:2605920[http] title:_"Shock Stock (2012) (TV Episode)  - Season 2 | Episode 4  - FlixxTV" (2011)_>,
#  <Movie id:0050439[http] title:_The Girl in Black Stockings (1957)_>,
#  <Movie id:1460652[http] title:_Stock Shock (2009) (V)_>,
#  <Movie id:0454006[http] title:_"Chicks to Chicks" (1984)_>,
#  <Movie id:0208092[http] title:_Snatch (2000)_>]

# %%
lock_stock_imdb_id = '0120735'
lock_stock_imdb = imdb.get_movie(lock_stock_imdb_id)
lock_stock_imdb.summary()
# Out:
# u"Movie\n=====\nTitle: Lock, Stock and Two Smoking Barrels (1998)\nGenres: Comedy, Crime.\nDirector: Guy Ritchie.\nWriter: Guy Ritchie.\nCast: Jason Flemyng (Tom), Dexter Fletcher (Soap), Nick Moran (Eddy), Jason Statham (Bacon), Steven Mackintosh (Winston).\nRuntime: 107, 120::(director's cut).\nCountry: UK.\nLanguage: English.\nRating: 8.2 (436339 votes).\nPlot: Four Jack-the-lads find themselves heavily - seriously heavily - in debt to an East End hard man and his enforcers after a crooked card game. Overhearing their neighbours in the next flat plotting to hold up a group of out-of-their-depth drug growers, our heros decide to stitch up the robbers in turn. In a way the confusion really starts when a pair of antique double-barrelled shotguns go missing in a completely different scam."

# %% [markdown]
# ***Print Genres and Poster***

# %%
lock_stock_imdb['genres']
# Out:
# [u'Comedy', u'Crime']

# %%
lock_stock_imdb_poster_path = lock_stock_imdb['full-size cover url']
print(lock_stock_imdb_poster_path)
# Out:
# https://images-na.ssl-images-amazon.com/images/M/MV5BMTAyN2JmZmEtNjAyMy00NzYwLThmY2MtYWQ3OGNhNjExMmM4XkEyXkFqcGdeQXVyNDk3NzU2MTQ@.jpg

# %%
Image(lock_stock_imdb_poster_path)

# %% [markdown]
# ### TMDb Exploration

# %% [markdown]
# ***Search for Movie by Name & Print Summary***

# %%
def getMoviesByString(title_text):
    search = tmdb.Search()
    response = search.movie(query=title_text)
    return search.results

# %%
def getMoviesByTMDBId(tmdb_id):
    movie = tmdb.Movies(tmdb_id)
    return movie.info()

# %%
def getMoviesByIMDBId(imdb_id):
    find = tmdb.Find(id=imdb_id)
    response = find.info(external_source="imdb_id")
    return response['movie_results']

# %%
getMoviesByString('lock two') # search to yield more than one result...for sake of understanding output
# Out:
# [{u'adult': False,
#   u'backdrop_path': u'/kzeR7BA0htJ7BeI6QEUX3PVp39s.jpg',
#   u'genre_ids': [35, 80],
#   u'id': 100,
#   u'original_language': u'en',
#   u'original_title': u'Lock, Stock and Two Smoking Barrels',
#   u'overview': u'A card sharp and his unwillingly-enlisted friends need to make a lot of cash quick after losing a sketchy poker match. To do this they decide to pull a heist on a small-time gang who happen to be operating out of the flat next door.',
#   u'popularity': 1.84715,
#   u'poster_path': u'/qV7QaSf7f7yC2lc985zfyOJIAIN.jpg',
#   u'release_date': u'1998-03-05',
#   u'title': u'Lock, Stock and Two Smoking Barrels',
#   u'video': False,
#   u'vote_average': 7.4,
#   u'vote_count': 1398},
#  {u'adult': False,
#   u'backdrop_path': None,
#   u'genre_ids': [10751],
#   u'id': 324645,
#   u'original_language': u'en',
#   u'original_title': u'Four Winds Island Part Two The Lockwood Jewels',
#   u'overview': u"Adventure serial about a school girl's search for lost jewels on a small Sicilian island.",
#   u'popularity': 1.000165,
#   u'poster_path': u'/4Q7GIOvM1q5f6JbP6yLjbToak7M.jpg',
#   u'release_date': u'1961-01-01',
#   u'title': u'Four Winds Island Part Two The Lockwood Jewels',
#   u'video': False,
#   u'vote_average': 0,
#   u'vote_count': 0}]

# %%
lock_stock_tmdb_id = 100
lock_stock_tmdb = getMoviesByTMDBId(lock_stock_tmdb_id)
lock_stock_tmdb
# Out:
# {u'adult': False,
#  u'backdrop_path': u'/kzeR7BA0htJ7BeI6QEUX3PVp39s.jpg',
#  u'belongs_to_collection': None,
#  u'budget': 1350000,
#  u'genres': [{u'id': 35, u'name': u'Comedy'}, {u'id': 80, u'name': u'Crime'}],
#  u'homepage': u'http://www.universalstudiosentertainment.com/lock-stock-and-two-smoking-barrels/',
#  u'id': 100,
#  u'imdb_id': u'tt0120735',
#  u'original_language': u'en',
#  u'original_title': u'Lock, Stock and Two Smoking Barrels',
#  u'overview': u'A card sharp and his unwillingly-enlisted friends need to make a lot of cash quick after losing a sketchy poker match. To do this they decide to pull a heist on a small-time gang who happen to be operating out of the flat next door.',
#  u'popularity': 0.84715,
#  u'poster_path': u'/qV7QaSf7f7yC2lc985zfyOJIAIN.jpg',
#  u'production_companies': [{u'id': 146, u'name': u'Handmade Films Ltd.'},
#   {u'id': 491, u'name': u'Summit Entertainment'},
#   {u'id': 1382, u'name': u'PolyGram Filmed Entertainment'},
#   {u'id': 13419, u'name': u'SKA Films'},
#   {u'id': 21920, u'name': u'The Steve Tisch Company'}],
#  u'production_countries': [{u'iso_3166_1': u'GB', u'name': u'United Kingdom'}],
#  u'release_date': u'1998-03-05',
#  u'revenue': 3897569,
#  u'runtime': 105,
#  u'spoken_languages': [{u'iso_639_1': u'en', u'name': u'English'}],
#  u'status': u'Released',
#  u'tagline': u'A Disgrace to Criminals Everywhere.',
#  u'title': u'Lock, Stock and Two Smoking Barrels',
#  u'video': False,
#  u'vote_average': 7.4,
#  u'vote_count': 1399}

# %%
getMoviesByIMDBId("tt"+lock_stock_imdb_id) # to demonstrate that we can pull TMDb info with IMDb id
# Out:
# [{u'adult': False,
#   u'backdrop_path': u'/kzeR7BA0htJ7BeI6QEUX3PVp39s.jpg',
#   u'genre_ids': [35, 80],
#   u'id': 100,
#   u'original_language': u'en',
#   u'original_title': u'Lock, Stock and Two Smoking Barrels',
#   u'overview': u'A card sharp and his unwillingly-enlisted friends need to make a lot of cash quick after losing a sketchy poker match. To do this they decide to pull a heist on a small-time gang who happen to be operating out of the flat next door.',
#   u'popularity': 1.84715,
#   u'poster_path': u'/qV7QaSf7f7yC2lc985zfyOJIAIN.jpg',
#   u'release_date': u'1998-03-05',
#   u'title': u'Lock, Stock and Two Smoking Barrels',
#   u'video': False,
#   u'vote_average': 7.4,
#   u'vote_count': 1398}]

# %% [markdown]
# ***Print Genres and Poster***

# %%
def getMoviePosterURL(movie):
    base_url = "https://image.tmdb.org/t/p/"
    file_size = "w500"
    poster_path = movie['poster_path']
    poster_url = base_url+file_size+poster_path
    return poster_url

# %%
def getMoviePoster(movie):
    return getMoviePosterByPath(movie['poster_path'], movie['title'])

# %%
lock_stock_tmdb['genres']
# Out:
# [{u'id': 35, u'name': u'Comedy'}, {u'id': 80, u'name': u'Crime'}]

# %%
lock_stock_tmdb_poster_path = getMoviePosterURL(lock_stock_tmdb)
print(lock_stock_tmdb_poster_path)
# Out:
# https://image.tmdb.org/t/p/w500/qV7QaSf7f7yC2lc985zfyOJIAIN.jpg

# %%
Image(lock_stock_tmdb_poster_path)

# %% [markdown]
# ### Top 10 Movies in 2016 (By TMDb Popularity / User Score)

# %%
discover = tmdb.Discover()

# movies sorted by user votes...can be by TMDb's "popularity score" (sort_by='popularity.desc') or...
# ...TMDb's "average user score" (sort_by='vote_average.desc')
# exclude movies with less than specified number of votes
movies_2016 = discover.movie(primary_release_year=2016, sort_by='vote_average.desc', vote_count_gte=50)

# %%
movies_2016
# Out:
# {u'page': 1,
#  u'results': [{u'adult': False,
#    u'backdrop_path': u'/6vkhRvsRvWpmaRVyCXaxTkIEb7j.jpg',
#    u'genre_ids': [16, 18, 14, 10749],
#    u'id': 372058,
#    u'original_language': u'ja',
#    u'original_title': u'\u541b\u306e\u540d\u306f\u3002',
#    u'overview': u'High schoolers Mitsuha and Taki are complete strangers living separate lives. But one night, they suddenly switch places. Mitsuha wakes up in Taki\u2019s body, and he in hers. This bizarre occurrence continues to happen randomly, and the two must adjust their lives around each other.',
#    u'popularity': 6.706595,
#    u'poster_path': u'/xq1Ugd62d23K2knRUx6xxuALTZB.jpg',
#    u'release_date': u'2016-08-26',
#    u'title': u'Your Name.',
#    u'video': False,
#    u'vote_average': 8.4,
#    u'vote_count': 335},
#   {u'adult': False,
#    u'backdrop_path': u'/w1WqcS6hT0PUWC3adG37NSUOGX5.jpg',
#    u'genre_ids': [10751, 16],
#    u'id': 399106,
#    u'original_language': u'en',
#    u'original_title': u'Piper',
#    u'overview': u'A mother bird tries to teach her little one how to find food by herself. In the process, she encounters a traumatic experience that she must overcome in order to survive.',
#    u'popularity': 3.325161,
#    u'poster_path': u'/jLRllZsubY8UWpeMyDLVXdRyEWi.jpg',
#    u'release_date': u'2016-06-16',
#    u'title': u'Piper',
#    u'video': False,
#    u'vote_average': 8.2,
#    u'vote_count': 309},
#   {u'adult': False,
#    u'backdrop_path': u'/fbvXdEELp3lHlRzXq85BoV7bcGl.jpg',
#    u'genre_ids': [10752, 18, 35],
#    u'id': 403450,
#    u'original_language': u'it',
#    u'original_title': u'In guerra per amore',
#    u'overview': u'Arturo loves Flora, daughter of a restaurant owner, but she has been promised in marriage to a Mafia boss.',
#    u'popularity': 1.332168,
#    u'poster_path': u'/6cA3IIv8SYZCxczQaMvjG42uSMC.jpg',
#    u'release_date': u'2016-10-27',
#    u'title': u'In guerra per amore',
#    u'video': False,
#    u'vote_average': 8.1,
#    u'vote_count': 61},
#   {u'adult': False,
#    u'backdrop_path': u'/9j4UaRypr19wz0BOofwvkPRm1Se.jpg',
#    u'genre_ids': [10749, 18, 10402],
#    u'id': 369557,
#    u'original_language': u'en',
#    u'original_title': u'Sing Street',
#    u'overview': u'A boy growing up in Dublin during the 1980s escapes his strained family life by starting a band to impress the mysterious girl he likes.',
#    u'popularity': 3.235652,
#    u'poster_path': u'/s0C78plmx3dFcO3WMnoXCz56FiN.jpg',
#    u'release_date': u'2016-04-15',
#    u'title': u'Sing Street',
#    u'video': False,
#    u'vote_average': 8.1,
#    u'vote_count': 413},
#   {u'adult': False,
#    u'backdrop_path': u'/hvRMQT6neHXApaJwLnMWMheTlpk.jpg',
#    u'genre_ids': [18],
#    u'id': 393729,
#    u'original_language': u'fr',
#    u'original_title': u'Divines',
#    u'overview': u'In a ghetto where religion and drug trafficking rub shoulders, Dounia has a lust for power and success. Supported by Maimouna, her best friend, she decides to follow in the footsteps of Rebecca, a respected dealer. But her encounter with Djigui, a young, disturbingly sensual dancer, throws her off course.',
#    u'popularity': 1.485363,
#    u'poster_path': u'/yTZw4CdK0cWac9ugayJLv09N4op.jpg',
#    u'release_date': u'2016-08-31',
#    u'title': u'Divines',
#    u'video': False,
#    u'vote_average': 8,
#    u'vote_count': 95},
#   {u'adult': False,
#    u'backdrop_path': u'/7JLq3aQV89IAL2wetJ5f5STswql.jpg',
#    u'genre_ids': [16, 18, 10751],
#    u'id': 393559,
#    u'original_language': u'fr',
#    u'original_title': u'Ma vie de courgette',
#    u'overview': u'After his mother\u2019s death, Zucchini is befriended by a kind police officer, Raymond, who accompanies him to his new foster home filled with other orphans his age. There, with the help of his newfound friends, Zucchini eventually learns to trust and love as he searches for a new family of his own.',
#    u'popularity': 2.436443,
#    u'poster_path': u'/5RBwmTlwLV2HlY1PNS6PuwL16sD.jpg',
#    u'release_date': u'2016-10-19',
#    u'title': u'My Life as a Zucchini',
#    u'video': False,
#    u'vote_average': 8,
#    u'vote_count': 52},
#   {u'adult': False,
#    u'backdrop_path': u'/l6Mmtu57qgw4NRuxEC0Vj6UMr2R.jpg',
#    u'genre_ids': [18, 36, 53],
#    u'id': 347938,
#    u'original_language': u'en',
#    u'original_title': u'11.22.63',
#    u'overview': u'An English teacher travels back in time to prevent the Kennedy assassination, but discovers he is attached to the life he has made in a bygone era.',
#    u'popularity': 1.608467,
#    u'poster_path': u'/5EJGeeuPy19EGDy8HErpbHba0yq.jpg',
#    u'release_date': u'2016-02-15',
#    u'title': u'11.22.63',
#    u'video': False,
#    u'vote_average': 8,
#    u'vote_count': 129},
#   {u'adult': False,
#    u'backdrop_path': u'/fhSkVpRCg5s9b8nmdSS77Q1onhv.jpg',
#    u'genre_ids': [99],
#    u'id': 407806,
#    u'original_language': u'en',
#    u'original_title': u'13th',
#    u'overview': u"An in-depth look at the prison system in the United States and how it reveals the nation's history of racial inequality.",
#    u'popularity': 1.295027,
#    u'poster_path': u'/zyv3omPVI9u5Kmem7l1xycnLCYP.jpg',
#    u'release_date': u'2016-10-07',
#    u'title': u'13th',
#    u'video': False,
#    u'vote_average': 7.9,
#    u'vote_count': 92},
#   {u'adult': False,
#    u'backdrop_path': u'/keQhqxE9i7wNQIM3W5B0iLnjaHW.jpg',
#    u'genre_ids': [53, 18, 10749],
#    u'id': 290098,
#    u'original_language': u'ko',
#    u'original_title': u'\uc544\uac00\uc528',
#    u'overview': u'Korea, 1930s. A con man hires a pickpocket to become the maid of a mysterious and fragile heiress, in an attempt to seize her wealth. But not everything goes according to plan.',
#    u'popularity': 2.920936,
#    u'poster_path': u'/wvzfK5QR6dGLwND8MCzWjsQWG4Q.jpg',
#    u'release_date': u'2016-06-01',
#    u'title': u'The Handmaiden',
#    u'video': False,
#    u'vote_average': 7.9,
#    u'vote_count': 215},
#   {u'adult': False,
#    u'backdrop_path': u'/1jvCKo7NOFKXRfpuifvG8tVZQsA.jpg',
#    u'genre_ids': [18, 12, 35],
#    u'id': 371645,
#    u'original_language': u'en',
#    u'original_title': u'Hunt for the Wilderpeople',
#    u'overview': u'Ricky is a defiant young city kid who finds himself on the run with his cantankerous foster uncle in the wild New Zealand bush. A national manhunt ensues, and the two are forced to put aside their differences and work together to survive.',
#    u'popularity': 3.982403,
#    u'poster_path': u'/2wxvvnHKdZRB31Drf7PbRzPb0mR.jpg',
#    u'release_date': u'2016-03-31',
#    u'title': u'Hunt for the Wilderpeople',
#    u'video': False,
#    u'vote_average': 7.9,
#    u'vote_count': 311},
#   {u'adult': False,
#    u'backdrop_path': u'/fp6X6yhgcxzxCpmM0EVC6V9B8XB.jpg',
#    u'genre_ids': [35, 18, 10402, 10749],
#    u'id': 313369,
#    u'original_language': u'en',
#    u'original_title': u'La La Land',
#    u'overview': u'Mia, an aspiring actress, serves lattes to movie stars in between auditions and Sebastian, a jazz musician, scrapes by playing cocktail party gigs in dingy bars, but as success mounts they are faced with decisions that begin to fray the fragile fabric of their love affair, and the dreams they worked so hard to maintain in each other threaten to rip them apart.',
#    u'popularity': 9.477253,
#    u'poster_path': u'/ylXCdC106IKiarftHkcacasaAcb.jpg',
#    u'release_date': u'2016-09-12',
#    u'title': u'La La Land',
#    u'video': False,
#    u'vote_average': 7.9,
#    u'vote_count': 2391},
#   {u'adult': False,
#    u'backdrop_path': u'/zaePnCmDgul7jtyn3622gsujEZz.jpg',
#    u'genre_ids': [18],
#    u'id': 334543,
#    u'original_language': u'en',
#    u'original_title': u'Lion',
#    u'overview': u'A five-year-old Indian boy gets lost on the streets of Calcutta, thousands of kilometers from home. He survives many challenges before being adopted by a couple in Australia; 25 years later, he sets out to find his lost family.',
#    u'popularity': 16.452144,
#    u'poster_path': u'/iBGRbLvg6kVc7wbS8wDdVHq6otm.jpg',
#    u'release_date': u'2016-11-24',
#    u'title': u'Lion',
#    u'video': False,
#    u'vote_average': 7.9,
#    u'vote_count': 689},
#   {u'adult': False,
#    u'backdrop_path': u'/nxc9naASvhPWdWeI7lkbkawirm1.jpg',
#    u'genre_ids': [80, 18, 9648],
#    u'id': 379170,
#    u'original_language': u'en',
#    u'original_title': u'Sherlock: The Abominable Bride',
#    u'overview': u'Sherlock Holmes and Dr. Watson find themselves in 1890s London in this holiday special.',
#    u'popularity': 3.955621,
#    u'poster_path': u'/tohC9Ytf7akG9tJcdLIRtW6QL8b.jpg',
#    u'release_date': u'2016-01-01',
#    u'title': u'Sherlock: The Abominable Bride',
#    u'video': False,
#    u'vote_average': 7.9,
#    u'vote_count': 494},
#   {u'adult': False,
#    u'backdrop_path': u'/4sCDMJ8ewMuL92mFTJQd4vkdPDe.jpg',
#    u'genre_ids': [99],
#    u'id': 410718,
#    u'original_language': u'en',
#    u'original_title': u'Before the Flood',
#    u'overview': u'A look at how climate change affects our environment and what society can do prevent the demise of endangered species, ecosystems, and native communities across the planet.',
#    u'popularity': 2.371133,
#    u'poster_path': u'/lOu2ETjnndhk89SgqK9lFb3Lb4i.jpg',
#    u'release_date': u'2016-10-21',
#    u'title': u'Before the Flood',
#    u'video': False,
#    u'vote_average': 7.9,
#    u'vote_count': 147},
#   {u'adult': False,
#    u'backdrop_path': u'/hzp6irYITiJc5JUA1GZhmbE10pD.jpg',
#    u'genre_ids': [12, 35, 18, 10749],
#    u'id': 334533,
#    u'original_language': u'en',
#    u'original_title': u'Captain Fantastic',
#    u'overview': u'A father living in the forests of the Pacific Northwest with his six young kids tries to assimilate back into society.',
#    u'popularity': 6.152609,
#    u'poster_path': u'/fnaGmGCWgGOQjCpM0TqKPZJ5x85.jpg',
#    u'release_date': u'2016-07-02',
#    u'title': u'Captain Fantastic',
#    u'video': False,
#    u'vote_average': 7.9,
#    u'vote_count': 781},
#   {u'adult': False,
#    u'backdrop_path': u'/l3NbEqQ9i5mkyVAxEYZU0mdYXow.jpg',
#    u'genre_ids': [18],
#    u'id': 374473,
#    u'original_language': u'en',
#    u'original_title': u'I, Daniel Blake',
#    u'overview': u'A middle aged carpenter, who requires state welfare after injuring himself, is joined by a single mother in a similar scenario.',
#    u'popularity': 4.619999,
#    u'poster_path': u'/8SkoLyL8HOpx2iyngjlxurGQSGX.jpg',
#    u'release_date': u'2016-10-21',
#    u'title': u'I, Daniel Blake',
#    u'video': False,
#    u'vote_average': 7.9,
#    u'vote_count': 139},
#   {u'adult': False,
#    u'backdrop_path': u'/1yJopDnHURAlQqnmwsh6eqkZkdf.jpg',
#    u'genre_ids': [35, 18],
#    u'id': 381341,
#    u'original_language': u'it',
#    u'original_title': u'Perfetti sconosciuti',
#    u'overview': u'During a dinner, a group of friends decide to share whatever text message or phone call they will receive during the evening - and all hell breaks loose.',
#    u'popularity': 2.878513,
#    u'poster_path': u'/52ECxNeaekqZWXaBOq0jQEjUo8w.jpg',
#    u'release_date': u'2016-02-11',
#    u'title': u'Perfect Strangers',
#    u'video': False,
#    u'vote_average': 7.8,
#    u'vote_count': 440},
#   {u'adult': False,
#    u'backdrop_path': u'/uZSDYPwqTKGUbLqhcXgQ4qQkqK2.jpg',
#    u'genre_ids': [18],
#    u'id': 377273,
#    u'original_language': u'pt',
#    u'original_title': u'Aquarius',
#    u'overview': u'Clara, a 65-year-old widow and retired music critic, was born into a wealthy and traditional family in Recife, Brazil. She is the last resident of the Aquarius, an original two-story building, built in the 1940s, in the upper-class, seaside Boa Viagem Avenue. All the neighboring apartments have already been acquired by a company which has other plans for that plot.',
#    u'popularity': 1.275686,
#    u'poster_path': u'/gxuT8EbgXsHq02LLDYuXdTD963V.jpg',
#    u'release_date': u'2016-09-01',
#    u'title': u'Aquarius',
#    u'video': False,
#    u'vote_average': 7.8,
#    u'vote_count': 63},
#   {u'adult': False,
#    u'backdrop_path': u'/wWRSXXH4SNSPkHBnQLKBxDp9Xuj.jpg',
#    u'genre_ids': [18, 10751, 35],
#    u'id': 404378,
#    u'original_language': u'en',
#    u'original_title': u'A Street Cat Named Bob',
#    u'overview': u'Based on the international best selling book. The true feel good story of how James Bowen, a busker and recovering drug addict, had his life transformed when he met a stray ginger cat.',
#    u'popularity': 2.830428,
#    u'poster_path': u'/6gJ4ENXs2thjxe0mK8TjAZOOPMT.jpg',
#    u'release_date': u'2016-11-04',
#    u'title': u'A Street Cat Named Bob',
#    u'video': False,
#    u'vote_average': 7.8,
#    u'vote_count': 93},
#   {u'adult': False,
#    u'backdrop_path': u'/vifqDyPOB6jd5vwP2SIqWNtXUHu.jpg',
#    u'genre_ids': [36, 18],
#    u'id': 381284,
#    u'original_language': u'en',
#    u'original_title': u'Hidden Figures',
#    u'overview': u'The untold story of Katherine G. Johnson, Dorothy Vaughan and Mary Jackson \u2013 brilliant African-American women working at NASA and serving as the brains behind one of the greatest operations in history \u2013 the launch of astronaut John Glenn into orbit. The visionary trio crossed all gender and race lines to inspire generations to dream big.',
#    u'popularity': 18.78631,
#    u'poster_path': u'/6cbIDZLfwUTmttXTmNi8Mp3Rnmg.jpg',
#    u'release_date': u'2016-12-10',
#    u'title': u'Hidden Figures',
#    u'video': False,
#    u'vote_average': 7.7,
#    u'vote_count': 942}],
#  u'total_pages': 17,
#  u'total_results': 336}

# %%
num_top_movies = 10  #note: only 20 movies fit on each results page

idx = range(0, num_top_movies)
cols = ['movie_id', 'title', 'vote_average', 'tmdb_popularity', 'genres']

tmdb_df = pd.DataFrame(index=idx, columns=cols)

# %%
for i in range(0, num_top_movies):
    tmdb_df['movie_id'][i] = movies_2016['results'][i]['id']
    tmdb_df['title'][i] = movies_2016['results'][i]['title']
    tmdb_df['vote_average'][i] = movies_2016['results'][i]['vote_average']
    tmdb_df['tmdb_popularity'][i] = movies_2016['results'][i]['popularity']
    tmdb_df['genres'][i] = movies_2016['results'][i]['genre_ids']

# %%
tmdb_df
# Out:
#   movie_id                      title vote_average tmdb_popularity  \
# 0   372058                 Your Name.          8.4          6.7066
# 1   399106                      Piper          8.2         3.32516
# 2   403450        In guerra per amore          8.1         1.33217
# 3   369557                Sing Street          8.1         3.23565
# 4   393729                    Divines            8         1.48536
# 5   393559      My Life as a Zucchini            8         2.43644
# 6   347938                   11.22.63            8         1.60847
# 7   407806                       13th          7.9         1.29503
# 8   290098             The Handmaiden          7.9         2.92094
# 9   371645  Hunt for the Wilderpeople          7.9          3.9824
#
#                 genres
# 0  [16, 18, 14, 10749]
# 1          [10751, 16]
# 2      [10752, 18, 35]
# 3   [10749, 18, 10402]
# 4                 [18]
# 5      [16, 18, 10751]
# 6         [18, 36, 53]
# 7                 [99]
# 8      [53, 18, 10749]
# 9         [18, 12, 35]

# %% [markdown]
# ### Analyze Genre Pairs

# %% [markdown]
# ***Table of Genres with IDs***

# %%
num_genres = len(tmdb.Genres().list()['genres'])

idx = range(0, num_genres)
cols = ['genre_id', 'genre']

tmdb_genre_df = pd.DataFrame(index=idx, columns=cols)

# %%
for i in range(0, num_genres):
    tmdb_genre_df['genre_id'][i] = tmdb.Genres().list()['genres'][i].values()[0]
    tmdb_genre_df['genre'][i] = tmdb.Genres().list()['genres'][i].values()[1]

# %%
tmdb_genre_df
# Out:
#    genre_id            genre
# 0        28           Action
# 1        12        Adventure
# 2        16        Animation
# 3        35           Comedy
# 4        80            Crime
# 5        99      Documentary
# 6        18            Drama
# 7     10751           Family
# 8        14          Fantasy
# 9        36          History
# 10       27           Horror
# 11    10402            Music
# 12     9648          Mystery
# 13    10749          Romance
# 14      878  Science Fiction
# 15    10770         TV Movie
# 16       53         Thriller
# 17    10752              War
# 18       37          Western

# %% [markdown]
# ***Create Table of 500 Movies with Genre Listings***

# %%
max_page = 25 #set to 25 since there are just over 500 entries with '2016' and 'vote_count'>=25 (20 entries per page!)
movies_per_page = 20 #always 20 entries per page

# %%
idx = range(0, max_page * movies_per_page)
cols = ['num_genres', 'id_1', 'id_2', 'id_3', 'id_4', 'id_5', 'id_6', 'id_7']

movies_genres_table = pd.DataFrame(index=idx, columns=cols)

# %%
for i in range(0, max_page):
    movies_page = discover.movie(page=(i+1), primary_release_year=2016, vote_count_gte=25)
    
    for j in range(0, movies_per_page):
        genre_list = movies_page['results'][j]['genre_ids']
        row_num = i * movies_per_page + j
        movies_genres_table.loc[row_num][0] = len(genre_list)

        for k in range(0, len(genre_list)):
            movies_genres_table.loc[row_num][k+1] = genre_list[k]

# %%
movies_genres_table
# Out:
#     num_genres   id_1   id_2   id_3   id_4   id_5 id_6 id_7
# 0            5     16     35     18  10751  10402  NaN  NaN
# 1            3     12     28     14    NaN    NaN  NaN  NaN
# 2            4     12     16     35  10751    NaN  NaN  NaN
# 3            4     28     12     35  10749    NaN  NaN  NaN
# 4            4     28     18    878  10752    NaN  NaN  NaN
# 5            2     18    878    NaN    NaN    NaN  NaN  NaN
# 6            4     28     12     14    878    NaN  NaN  NaN
# 7            2     28    878    NaN    NaN    NaN  NaN  NaN
# 8            2     28     27    NaN    NaN    NaN  NaN  NaN
# 9            4     16     12  10751     35    NaN  NaN  NaN
# 10           2     36     18    NaN    NaN    NaN  NaN  NaN
# 11           3     18     36  10752    NaN    NaN  NaN  NaN
# 12           4     12     18  10749    878    NaN  NaN  NaN
# 13           4     28     12     14    878    NaN  NaN  NaN
# 14           1     18    NaN    NaN    NaN    NaN  NaN  NaN
# 15           4     28     12     14    878    NaN  NaN  NaN
# 16           1     28    NaN    NaN    NaN    NaN  NaN  NaN
# 17           3     18     14     12    NaN    NaN  NaN  NaN
# 18           3     18     36     53    NaN    NaN  NaN  NaN
# 19           3     80     53     18    NaN    NaN  NaN  NaN
# 20           2     18     53    NaN    NaN    NaN  NaN  NaN
# 21           3     28     12     14    NaN    NaN  NaN  NaN
# 22           5     28     80     18   9648     53  NaN  NaN
# 23           4     28     80     14    878    NaN  NaN  NaN
# 24           2     18     53    NaN    NaN    NaN  NaN  NaN
# 25           1     35    NaN    NaN    NaN    NaN  NaN  NaN
# 26           6     28     12     35     80   9648   53  NaN
# 27           1     53    NaN    NaN    NaN    NaN  NaN  NaN
# 28           4     35     18  10402  10749    NaN  NaN  NaN
# 29           4     28     12     14     53    NaN  NaN  NaN
# ..         ...    ...    ...    ...    ...    ...  ...  ...
# 470          3    878     14     27    NaN    NaN  NaN  NaN
# 471          0    NaN    NaN    NaN    NaN    NaN  NaN  NaN
# 472          1     53    NaN    NaN    NaN    NaN  NaN  NaN
# 473          2    878     28    NaN    NaN    NaN  NaN  NaN
# 474          1     35    NaN    NaN    NaN    NaN  NaN  NaN
# 475          2  10402     35    NaN    NaN    NaN  NaN  NaN
# 476          1     35    NaN    NaN    NaN    NaN  NaN  NaN
# 477          2     36     99    NaN    NaN    NaN  NaN  NaN
# 478          1     35    NaN    NaN    NaN    NaN  NaN  NaN
# 479          1     35    NaN    NaN    NaN    NaN  NaN  NaN
# 480          2     35     18    NaN    NaN    NaN  NaN  NaN
# 481          2  10752     99    NaN    NaN    NaN  NaN  NaN
# 482          1     35    NaN    NaN    NaN    NaN  NaN  NaN
# 483          2     16     99    NaN    NaN    NaN  NaN  NaN
# 484          4     18  10752     36  10749    NaN  NaN  NaN
# 485          1     35    NaN    NaN    NaN    NaN  NaN  NaN
# 486          2     35     18    NaN    NaN    NaN  NaN  NaN
# 487          3     53     35     27    NaN    NaN  NaN  NaN
# 488          4     53     18   9648    878    NaN  NaN  NaN
# 489          2  10749     35    NaN    NaN    NaN  NaN  NaN
# 490          1     35    NaN    NaN    NaN    NaN  NaN  NaN
# 491          2  10402     99    NaN    NaN    NaN  NaN  NaN
# 492          4     53     28     18     36    NaN  NaN  NaN
# 493          1     35    NaN    NaN    NaN    NaN  NaN  NaN
# 494          1     18    NaN    NaN    NaN    NaN  NaN  NaN
# 495          3  10751     18     35    NaN    NaN  NaN  NaN
# 496          3    878     28     27    NaN    NaN  NaN  NaN
# 497          1     18    NaN    NaN    NaN    NaN  NaN  NaN
# 498          1     35    NaN    NaN    NaN    NaN  NaN  NaN
# 499          1     35    NaN    NaN    NaN    NaN  NaN  NaN
#
# [500 rows x 8 columns]

# %% [markdown]
# ***Create Table Showing How Genres Relate to Eachother***

# %%
idx = tmdb_genre_df['genre_id']
cols = tmdb_genre_df['genre_id']

genre_pairs_table = pd.DataFrame(index=idx, columns=cols)
genre_pairs_table = genre_pairs_table.fillna(0)

# %%
total_movies = len(movies_genres_table)

for row_num in range(0, total_movies):

    num_genres = movies_genres_table.iloc[row_num, 0]
    
    for i in range(0, num_genres):

        for j in range(0, num_genres):

            x = movies_genres_table.iloc[row_num, i+1]
            y = movies_genres_table.iloc[row_num, j+1]
            genre_pairs_table.loc[x, y] = genre_pairs_table.loc[x, y] + 1

# %%
genre_pairs_table
# Out:
# genre_id  28     12     16     35     80     99     18     10751  14     \
# genre_id
# 28          102     27      9     23     15      0     30      4     14
# 12           27     60     14     21      2      0     18     15     20
# 16            9     14     31     18      1      1      6     20      5
# 35           23     21     18    174      5      1     52     19      9
# 80           15      2      1      5     41      1     23      0      1
# 99            0      0      1      1      1     23      0      0      0
# 18           30     18      6     52     23      0    226      6     10
# 10751         4     15     20     19      0      0      6     28      4
# 14           14     20      5      9      1      0     10      4     35
# 36            4      2      0      2      0      1     20      0      0
# 27           12      2      0     10      4      0     11      0      4
# 10402         0      0      1      9      0      3      7      2      0
# 9648          4      2      0      4      6      0     13      0      2
# 10749         3      6      1     26      0      0     36      1      5
# 878          30     15      3      7      2      0     12      1     10
# 10770         1      1      1      3      0      0      1      1      0
# 53           32      8      0      9     29      0     52      0      7
# 10752         6      0      0      3      0      1     11      0      0
# 37            4      2      0      0      2      0      3      0      0
#
# genre_id  36     27     10402  9648   10749  878    10770  53     10752  37
# genre_id
# 28            4     12      0      4      3     30      1     32      6      4
# 12            2      2      0      2      6     15      1      8      0      2
# 16            0      0      1      0      1      3      1      0      0      0
# 35            2     10      9      4     26      7      3      9      3      0
# 80            0      4      0      6      0      2      0     29      0      2
# 99            1      0      3      0      0      0      0      0      1      0
# 18           20     11      7     13     36     12      1     52     11      3
# 10751         0      0      2      0      1      1      1      0      0      0
# 14            0      4      0      2      5     10      0      7      0      0
# 36           24      0      0      0      2      0      1      7      3      0
# 27            0     70      1      8      1     11      2     37      0      0
# 10402         0      1     17      1      4      1      2      1      0      0
# 9648          0      8      1     22      0      1      0     13      0      0
# 10749         2      1      4      0     50      2      0      5      3      0
# 878           0     11      1      1      2     46      2     11      1      0
# 10770         1      2      2      0      0      2      6      1      0      0
# 53            7     37      1     13      5     11      1    128      4      2
# 10752         3      0      0      0      3      1      0      4     16      0
# 37            0      0      0      0      0      0      0      2      0      6

# %%
genre_pairs_table_names = genre_pairs_table

new_idx = tmdb_genre_df['genre']
new_cols = tmdb_genre_df['genre']

genre_pairs_table_names.columns = new_cols
genre_pairs_table_names = genre_pairs_table_names.set_index(new_idx)

# %%
genre_pairs_table_names
# Out:
# genre            Action  Adventure  Animation  Comedy  Crime  Documentary  \
# genre
# Action              102         27          9      23     15            0
# Adventure            27         60         14      21      2            0
# Animation             9         14         31      18      1            1
# Comedy               23         21         18     174      5            1
# Crime                15          2          1       5     41            1
# Documentary           0          0          1       1      1           23
# Drama                30         18          6      52     23            0
# Family                4         15         20      19      0            0
# Fantasy              14         20          5       9      1            0
# History               4          2          0       2      0            1
# Horror               12          2          0      10      4            0
# Music                 0          0          1       9      0            3
# Mystery               4          2          0       4      6            0
# Romance               3          6          1      26      0            0
# Science Fiction      30         15          3       7      2            0
# TV Movie              1          1          1       3      0            0
# Thriller             32          8          0       9     29            0
# War                   6          0          0       3      0            1
# Western               4          2          0       0      2            0
#
# genre            Drama  Family  Fantasy  History  Horror  Music  Mystery  \
# genre
# Action              30       4       14        4      12      0        4
# Adventure           18      15       20        2       2      0        2
# Animation            6      20        5        0       0      1        0
# Comedy              52      19        9        2      10      9        4
# Crime               23       0        1        0       4      0        6
# Documentary          0       0        0        1       0      3        0
# Drama              226       6       10       20      11      7       13
# Family               6      28        4        0       0      2        0
# Fantasy             10       4       35        0       4      0        2
# History             20       0        0       24       0      0        0
# Horror              11       0        4        0      70      1        8
# Music                7       2        0        0       1     17        1
# Mystery             13       0        2        0       8      1       22
# Romance             36       1        5        2       1      4        0
# Science Fiction     12       1       10        0      11      1        1
# TV Movie             1       1        0        1       2      2        0
# Thriller            52       0        7        7      37      1       13
# War                 11       0        0        3       0      0        0
# Western              3       0        0        0       0      0        0
#
# genre            Romance  Science Fiction  TV Movie  Thriller  War  Western
# genre
# Action                 3               30         1        32    6        4
# Adventure              6               15         1         8    0        2
# Animation              1                3         1         0    0        0
# Comedy                26                7         3         9    3        0
# Crime                  0                2         0        29    0        2
# Documentary            0                0         0         0    1        0
# Drama                 36               12         1        52   11        3
# Family                 1                1         1         0    0        0
# Fantasy                5               10         0         7    0        0
# History                2                0         1         7    3        0
# Horror                 1               11         2        37    0        0
# Music                  4                1         2         1    0        0
# Mystery                0                1         0        13    0        0
# Romance               50                2         0         5    3        0
# Science Fiction        2               46         2        11    1        0
# TV Movie               0                2         6         1    0        0
# Thriller               5               11         1       128    4        2
# War                    3                1         0         4   16        0
# Western                0                0         0         2    0        6

# %% [markdown]
# *Observations:*
#
# 1. Of the 50 movies that listed "Romance" as a genre, 36 also listed "Drama" as a genre and just 1 listed "Horror" as a genre.
# 2. Of the 46 movies that listed "Science Fiction" as a genre, 30 also listed "Action" as a genre.
# 3. Movies categorized in the "Documentary" or "Horror" genres often do *not* list multiple genres, i.e. these genres are "pure".

# %% [markdown]
# ***Total Number of Genre Listings for 500 Movies***

# %%
idx = tmdb_genre_df['genre']
cols = ['num_movies_with_genre']

genre_totals = pd.DataFrame(index=idx, columns=cols)

# %%
for i in range(0, len(genre_totals)):
    genre_totals.iloc[i,0] = genre_pairs_table_names.ix[tmdb_genre_df['genre'][i], tmdb_genre_df['genre'][i]]

# %%
genre_totals
# Out:
#                 num_movies_with_genre
# genre
# Action                            102
# Adventure                          60
# Animation                          31
# Comedy                            174
# Crime                              41
# Documentary                        23
# Drama                             226
# Family                             28
# Fantasy                            35
# History                            24
# Horror                             70
# Music                              17
# Mystery                            22
# Romance                            50
# Science Fiction                    46
# TV Movie                            6
# Thriller                          128
# War                                16
# Western                             6

# %% [markdown]
# ***Check that Genre Totals Match***

# %%
sum(genre_totals.iloc[:, 0])
# Out:
# 1105

# %%
sum(movies_genres_table.loc[:,'num_genres'])
# Out:
# 1105

# %%
def getMoviePosterByPath(poster_path, filename):
    base_url = "https://image.tmdb.org/t/p/"
    file_size = "w500"
    poster_uri = base_url+file_size+poster_path
    local_filname = filename + ".jpg"
    # Download and save file locally.
    urllib.urlretrieve(poster_uri, local_filname)
    return local_filname

# %%
def loadGenres():
    return tmdb.Genres().list()

# %%
print loadGenres()

# %%
def getMoviesByGenreId(genre_id):
    return tmdb.Genres(id=genre_id).movies()

# %%
print getMoviesByGenreId(28)

# %%
movie = getMoviesByString("The Bourne Ult")
print "Genres for " + movie[0]['title'] + " include: " 
print movie[0]['genre_ids']
poster_local_filname = getMoviePosterByPath(movie[0]['poster_path'], movie[0]['title'])
Image(poster_local_filname)
